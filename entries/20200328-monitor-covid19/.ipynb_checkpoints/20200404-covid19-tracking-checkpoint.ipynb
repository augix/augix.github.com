# %%
#system('./git.pull.sh', intern=T)
# Out:
# [1] "Already up to date." "Already up to date."

# %%
source('./20200402-covid19-tracking-functions.R')
# get data
us.states.case = get.us.states(count_type = 'cases',level = 'state')
us.states.death = get.us.states(count_type = 'deaths',level = 'state')
chinese.provinces.case = get.china.provinces(count_type = 'province_confirmedCount',level = 'provinceEnglishName')
chinese.provinces.death = get.china.provinces(count_type = 'province_deadCount',level = 'provinceEnglishName')
world.provinces.case = get.world.provinces(count_type = 'province_confirmedCount',level = 'provinceEnglishName')
world.provinces.death = get.world.provinces(count_type = 'province_deadCount',level = 'provinceEnglishName')
# Out:
# Attaching package: ‘gplots’
#
#
# The following object is masked from ‘package:stats’:
#
#     lowess
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# make plots

## plot 1a China growth: 2nd wave
pdf(paste('f1a_china_case_growth',Sys.Date(),'pdf',sep='.'),w=5,h=10)
main='China new cases, 2nd wave'
day1='03-01'
xlab='Days since March 01'
ylab='Cumulative'
plot.points=T
adjust.label=F
add.total=T
add.double=T
new = chinese.provinces.case$new
new.2nd = new[,which(colnames(new) == day1):ncol(new)]
#new.2nd = new.2nd[rownames(new.2nd)!='Hubei',]
cum.2nd = t(apply(new.2nd,1,cumsum))
cum = cum.2nd

n=16 # regardless of the regression line
col=c('gray',col18)
layout(matrix(c(rep(1,16),2:(n+1)), nrow=8, ncol=4, byrow = TRUE))
cum2matplot(cum, n=n, align_n=100, day1=day1)
cum2matplot.aligned(cum, n=n, align_n=100, day1=day1)

day1='03-01'
xlab='Days since March 01'
main='China new cases, 2nd wave, except Hubei'
new = chinese.provinces.case$new
new.2nd = new[,which(colnames(new) == day1):ncol(new)]
new.2nd = new.2nd[rownames(new.2nd)!='Hubei',]
cum.2nd = t(apply(new.2nd,1,cumsum))
cum = cum.2nd
layout(matrix(c(rep(1,16),2:(n+1)), nrow=8, ncol=4, byrow = TRUE))
cum2matplot(cum, n=n, align_n=10, day1=day1)
cum2matplot.aligned(cum, n=n, align_n=10, day1=day1)

dev.off()


pdf(paste('f1b_china_case_heatmap',Sys.Date(),'pdf',sep='.'),w=10,h=5)
day1='01-23'
par(cex.main=0.8)
main = 'China confirmed cases'
library(RColorBrewer)
library(gplots)
breaks=c(0,1,4,16,64,256, 1024, 2048 )-0.1
col=c('white',brewer.pal(5,"Oranges"),'black')
new2heatmap(chinese.provinces.case$new,n=nrow(new.2nd),day1=day1)
dev.off()
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “148 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “155 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “3 y values <= 0 omitted from logarithmic plot”
# png
#   2
# Warning message in heatmap.2(mat[1:n, ], breaks = breaks, col = col, trace = "none", :
# “Discrepancy: Rowv is FALSE, while dendrogram is `both'. Omitting row dendogram.”
# Warning message in heatmap.2(mat[1:n, ], breaks = breaks, col = col, trace = "none", :
# “Discrepancy: Colv is FALSE, while dendrogram is `column'. Omitting column dendogram.”
# png
#   2

# %%
# US states
pdf(paste('US_states_death',Sys.Date(),'pdf',sep='.'),w=5,h=10)
day1='03-01'
main='US states, deaths'
xlab='Days'
ylab='Cumulative'
plot.points=T
adjust.label=F
add.total=T
add.double=T
cum = us.states.death$cum

n=16 # regardless of the regression line
col=c('gray',col18)
#pdf(paste('f4a_US_case_growth',Sys.Date(),'pdf',sep='.'),w=5,h=10)
layout(matrix(c(rep(1,16),2:(n+1)), nrow=8, ncol=4, byrow = TRUE))
cum2matplot(cum, n=n, align_n=10, day1=day1)
cum2matplot.aligned(cum, n=n, align_n=10, day1=day1)
dev.off()


# figure f5e

pdf(paste('f5e_China_vs_US_case_growth_aligned',Sys.Date(),'pdf',sep='.'),w=5,h=5)
main='China vs. US, cases'

China = chinese.provinces.case$cum
US = us.states.case$cum
overlapped.days = intersect(colnames(China),colnames(US))
combined = rbind(China[,overlapped.days],US[,overlapped.days])
cum=combined
col = c(rep('gray',nrow(China)),rep(col18,nrow(US)))

plot.points=F
adjust.label=F
add.total=F
add.double=F

n1=sum(China[, overlapped.days[length(overlapped.days)]]>=1000)
n2=sum(US[, overlapped.days[length(overlapped.days)]]>=1000)
col = c(rep('gray',n1),rep(col18,n2))
layout(matrix(c(rep(1,16),2:(n1+n2+1)), nrow=4, ncol=4, byrow = TRUE))
cum2matplot.aligned(cum, n=n1+n2, align_n=1000, day1='01-22')
dev.off()

pdf(paste('f5f_China_vs_US_death_growth_aligned',Sys.Date(),'pdf',sep='.'),w=5,h=5)
main='China vs. US, deaths'

China = chinese.provinces.death$cum
US = us.states.death$cum
overlapped.days = intersect(colnames(China),colnames(US))
combined = rbind(China[,overlapped.days],US[,overlapped.days])
cum=combined
col = c(rep('gray',nrow(China)),rep(col18,nrow(US)))

plot.points=F
adjust.label=F
add.total=F
add.double=F

n1=sum(China[, overlapped.days[length(overlapped.days)]]>=10)
n2=sum(US[, overlapped.days[length(overlapped.days)]]>=10)
col = c(rep('gray',n1),rep(col18,n2))
layout(matrix(c(rep(1,16),2:(n1+n2+1)), nrow=4, ncol=4, byrow = TRUE))
cum2matplot.aligned(cum, n=n1+n2, align_n=10, day1='01-22')
dev.off()



pdf(paste('f5g_World_vs_US_case_growth_aligned',Sys.Date(),'pdf',sep='.'),w=5,h=5)
main='World vs. US states, cases'

China = head(world.provinces.death$cum,10)
US = us.states.death$cum
overlapped.days = intersect(colnames(China),colnames(US))
combined = rbind(China[,overlapped.days],US[,overlapped.days])
cum=combined
col = c(rep('gray',nrow(China)),rep(col18,nrow(US)))

plot.points=F
adjust.label=F
add.total=F
add.double=F

n1=sum(China[, overlapped.days[length(overlapped.days)]]>=100)
n2=sum(US[, overlapped.days[length(overlapped.days)]]>=100)
col = c(rep('gray',n1),rep(col18,n2))
layout(matrix(c(rep(1,16),2:(n1+n2+1)), nrow=4, ncol=4, byrow = TRUE))
cum2matplot.aligned(cum, n=n1+n2, align_n=100, day1='01-22')
dev.off()

pdf(paste('f5h_World_vs_US_death_growth_aligned',Sys.Date(),'pdf',sep='.'),w=5,h=5)
main='World vs. US states, deaths'

China = head(world.provinces.death$cum,5)
US = us.states.death$cum
overlapped.days = intersect(colnames(China),colnames(US))
combined = rbind(China[,overlapped.days],US[,overlapped.days])
cum=combined
col = c(rep('gray',nrow(China)),rep(col18,nrow(US)))

plot.points=F
adjust.label=F
add.total=F
add.double=F

n1=sum(China[, overlapped.days[length(overlapped.days)]]>=10)
n2=sum(US[, overlapped.days[length(overlapped.days)]]>=10)
col = c(rep('gray',n1),rep(col18,n2))
layout(matrix(c(rep(1,16),2:(n1+n2+1)), nrow=4, ncol=4, byrow = TRUE))
cum2matplot.aligned(cum, n=n1+n2, align_n=10, day1='01-22')
dev.off()

pdf(paste('f5i_World_death_growth_aligned',Sys.Date(),'pdf',sep='.'),w=5,h=5)
main='World deaths'

cum=world.provinces.death$cum
col=col18
plot.points=F
adjust.label=F
add.total=F
add.double=F
layout(matrix(c(rep(1,16),2:17), nrow=4, ncol=4, byrow = TRUE))
cum2matplot.aligned(cum, n=16, align_n=10, day1='01-22')
dev.off()

pdf('world_total.pdf',w=5,h=5)
total = apply(world.provinces.death$cum,2,sum)
#names(total) = colnames(world.provinces.death$cum)
plot(total,type='l',log='y',cex=.5,pch=19)
days = length(total):1
#lines(days, total[length(total)]*2^((days-length(total))/6.5*2),col='gray')
points(length(total),total[length(total)],cex=.5,pch=19)
dev.off()
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “9 y values <= 0 omitted from logarithmic plot”
# png
#   2
# Warning message in matrix(c(rep(1, 16), 2:(n1 + n2 + 1)), nrow = 4, ncol = 4, byrow = TRUE):
# “data length [34] is not a sub-multiple or multiple of the number of rows [4]”
# png
#   2
# png
#   2
# png
#   2
# Warning message in matrix(c(rep(1, 16), 2:(n1 + n2 + 1)), nrow = 4, ncol = 4, byrow = TRUE):
# “data length [46] is not a sub-multiple or multiple of the number of rows [4]”
# png
#   2
# png
#   2
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “11 y values <= 0 omitted from logarithmic plot”
# png
#   2

# %%
# new plot for trending



plot_trend = function(res,min.cum=100,main='',col=col,last.day='',avg.n=7,log.xy='xy') {
	new = res$new; 
	cum = res$cum;
	if (last.day=='') {
		lastday = ncol(new)		
	} else {
		lastday = which(colnames(new)==last.day)
	}
	n=min(avg.n,lastday)
	days = seq(n,lastday,1)
	new.lastweek = new[,n:lastday]
	for (i in 1:(n-1)) {
		shift.i.day = new[,i:(lastday-n+i)]
		new.lastweek = new.lastweek + shift.i.day
	}
	new.lastweek = new.lastweek / (n)
	new.lastweek = cbind(matrix(NA,nrow=nrow(new),ncol=n-1), new.lastweek)
	
	if (ave.cum==T) {
		cum.lastweek = cum[,days]
		for (i in 1:6) {
			shift.i.day = cum[,i:(ncol(cum)-7+i)]
			cum.lastweek = cum.lastweek + shift.i.day
		}
		cum.lastweek = cum.lastweek / 7
	}
	
	x = cum[,days]
	y = new.lastweek[,days]
	x = as.matrix(x,ncol=length(days))
	y = as.matrix(y,ncol=length(days))
	provinces = rownames(x)
	
	#provinces = provinces[x[,ncol(x)]>=min.cum]
	#x = x[provinces,]
	#y = y[provinces,]
	
	col=col[provinces]
	main = paste(main,'on',last.day)
	matplot(t(x), t(y), main=main, log=log.xy,type='l',lty=1,pch=19,cex=0.5,col=col,xlim=xlim,ylim=ylim,xlab='Total',ylab='Weekly new reports')
	text(tail(t(x),1), tail(t(y),1), labels = rownames(y),pos=4,col=col,cex=0.5, offset=.5)
	points(tail(t(x),1), tail(t(y),1), labels = rownames(y),pch=19,pos=4,col=col,cex=1, offset=0.3)
}

ave.cum=F
avg.n=14
pdf('lastweek-case-linear.pdf',w=5,h=5)
china.new = apply(chinese.provinces.case$new,2,sum)
china.cum = apply(chinese.provinces.case$cum,2,sum)
new = rbind(china.new, world.provinces.case$new)
cum = rbind(china.cum, world.provinces.case$cum)
rownames(new)[1] = 'China'
rownames(cum)[1] = 'China'

res = list(new=new,cum=cum)
col=rep(col18,round(nrow(new)/18))
names(col)=rownames(new)

for (last.day in colnames(new)[2:ncol(new)]) {
	ylim=c(10,max(new)*1);xlim=c(10000,max(cum)*1.3)
	plot_trend(res, min.cum=1000,main='Confirmed cases',col=col,last.day=last.day,avg.n=avg.n,log.xy='')
}
dev.off()


ave.cum=F
avg.n=14
pdf('lastweek-case.pdf',w=5,h=5)
china.new = apply(chinese.provinces.case$new,2,sum)
china.cum = apply(chinese.provinces.case$cum,2,sum)
new = rbind(china.new, world.provinces.case$new)
cum = rbind(china.cum, world.provinces.case$cum)
rownames(new)[1] = 'China'
rownames(cum)[1] = 'China'

total.new = apply(new,2,sum)
total.cum = apply(cum,2,sum)
new = rbind(total.new, new)
cum = rbind(total.cum, cum)
rownames(new)[1] = 'Total'
rownames(cum)[1] = 'Total'

res = list(new=new,cum=cum)
col=rep(col18,round(nrow(new)/18))
names(col)=rownames(new)

for (last.day in colnames(new)[2:ncol(new)]) {

	ylim=c(10,max(new)*1);xlim=c(100,max(cum)*1.3)
	plot_trend(res, min.cum=1000,main='Confirmed cases',col=col,last.day=last.day,avg.n=avg.n)
}
dev.off()

pdf('lastweek-death.pdf',w=5,h=5)
china.new = apply(chinese.provinces.death$new,2,sum)
china.cum = apply(chinese.provinces.death$cum,2,sum)
new = rbind(china.new, world.provinces.death$new)
cum = rbind(china.cum, world.provinces.death$cum)
rownames(new)[1] = 'China'
rownames(cum)[1] = 'China'

total.new = apply(new,2,sum)
total.cum = apply(cum,2,sum)
new = rbind(total.new, new)
cum = rbind(total.cum, cum)
rownames(new)[1] = 'Total'
rownames(cum)[1] = 'Total'


res = list(new=new,cum=cum)

for (last.day in colnames(new)[2:ncol(new)]) {

	ylim=c(1,max(new)*1);xlim=c(10,max(cum)*1.3)
	plot_trend(res, min.cum=100,main='Deaths',col=col,last.day=last.day,avg.n=avg.n)
}
dev.off()

avg.n=14
pdf('lastweek-US-case.pdf',w=5,h=5)
new = us.states.case$new
cum = us.states.case$cum

total.new = apply(new,2,sum)
total.cum = apply(cum,2,sum)
new = rbind(total.new, new)
cum = rbind(total.cum, cum)
rownames(new)[1] = 'Total'
rownames(cum)[1] = 'Total'


res = list(new=new,cum=cum)
col=rep(col18,round(nrow(new)/18))
names(col)=rownames(new)
for (last.day in colnames(new)[2:ncol(new)]) {
	ylim=c(1,max(new)*1);xlim=c(1,max(cum)*1.3)
	plot_trend(res, min.cum=0,main='Confirmed cases',col=col,last.day=last.day,avg.n=avg.n)
}
dev.off()


pdf('lastweek-US-death.pdf',w=5,h=5)
new = us.states.death$new
cum = us.states.death$cum


total.new = apply(new,2,sum)
total.cum = apply(cum,2,sum)
new = rbind(total.new, new)
cum = rbind(total.cum, cum)
rownames(new)[1] = 'Total'
rownames(cum)[1] = 'Total'


res = list(new=new,cum=cum)

for (last.day in colnames(new)[2:ncol(new)]) {
	ylim=c(1,max(new)*1);xlim=c(1,max(cum)*1.3)
	plot_trend(res, min.cum=0,main='Deaths',col=col,last.day=last.day,avg.n=avg.n)
}
dev.off()
# Out:
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# png
#   2
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “182 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “182 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “182 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “182 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “182 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “182 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “182 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “182 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “170 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “170 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “168 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “168 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “167 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “167 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “165 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “165 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “162 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “162 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “159 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “159 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “159 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “159 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “159 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “159 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “158 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “158 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “316 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “316 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “474 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “474 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “632 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “632 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “790 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “790 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “948 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “948 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1106 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1108 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1264 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1269 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1422 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1430 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1580 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1592 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1738 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1755 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1895 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “1919 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2051 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2082 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2207 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2245 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2363 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2411 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2519 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2577 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2674 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2742 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2829 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2907 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2982 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3071 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3134 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3234 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3283 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3394 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3430 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3551 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3573 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3704 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3708 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3848 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3837 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3987 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “3962 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4123 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4081 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4252 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4196 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4376 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4305 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4493 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4408 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4604 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4508 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4711 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4601 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4810 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4690 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4904 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4775 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4993 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4858 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “5080 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “4934 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “5160 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# ...
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2180 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2180 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2223 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2223 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2266 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2266 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2304 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2304 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2341 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2341 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2373 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2373 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2401 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2401 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2425 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2425 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2446 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2446 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2465 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2465 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2483 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2483 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2499 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2500 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2512 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2514 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2523 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2526 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2529 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2533 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2534 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2539 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2538 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2544 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2542 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2549 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2545 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2553 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2547 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2556 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2549 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log = log):
# “2559 y values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 x values <= 0 omitted from logarithmic plot”
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “26 y values <= 0 omitted from logarithmic plot”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"labels" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"pos" is not a graphical parameter”
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"offset" is not a graphical parameter”
# png
#   2
